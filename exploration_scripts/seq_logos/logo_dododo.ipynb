# %%
import importlib

# standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# displays logos inline within the notebook;
# remove if using a python interpreter instead
# %matplotlib inline

# logomaker import
import logomaker

import create_matrix

# %%
importlib.reload(create_matrix)
# Out:
# <module 'create_matrix' from '/mnt/1.5_drive_0/16S_scrubbling/explore-16S-rRNA/exploration_scripts/seq_logos/create_matrix.py'>

# %% [markdown]
# # Candidatus Carsonella

# %%
my_df, coverages = create_matrix.create_matrix(
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Carsonella_21_tails.aln.fasta'
)

# f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])

# x = np.arange(-len(coverages), 0, 1)
# my_x_ticks = np.arange(1, 22, 1)[::-1]
my_x_ticks = np.array([0, 1, 6, 11, 16, 20])
ecoli_xticks = -np.array([21, 20, 15, 10, 5, 1])
# my_df.index = x



# create Logo object
my_logo = logomaker.Logo(my_df,
#                          ax=ax1,
                         font_name='DejaVu Sans',
                         color_scheme='colorblind_safe',
#                          color_scheme='grays',
#                          vpad=.1,
                         figsize=[14, 3],
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
# my_logo.highlight_position(p=2, color='gold', alpha=.5)
# my_logo.highlight_position(p=26, color='gold', alpha=.5)


# # style using Axes methods
my_logo.ax.set_ylabel('Frequency', fontsize=12)

my_logo.ax.set_xlabel('Position', fontsize=12)
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
# my_logo.ax.set_xticklabels('%d'%x for x in my_x_ticks+1)
# Out:
# [Text(0, 0, '-21'),
#  Text(1, 0, '-20'),
#  Text(6, 0, '-15'),
#  Text(11, 0, '-10'),
#  Text(16, 0, '-5'),
#  Text(20, 0, '-1')]

# %% [markdown]
# # Mycoplasma

# %%
my_df, coverages = create_matrix.create_matrix(
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Mycoplasma_21_tails.aln.fasta'
)

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])

my_x_ticks = np.array([0, 3, 8, 13, 18, 22, 23, 27, 29])
ecoli_xticks = np.array([23, 20, 15, 10, 5, 1, -1, -5, -7])



# create Logo object
my_logo = logomaker.Logo(my_df,
                         ax=ax1,
                         font_name='DejaVu Sans',
                         color_scheme='colorblind_safe',
#                          vpad=.1,
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
# my_logo.highlight_position(p=2, color='gold', alpha=.5)
# my_logo.highlight_position(p=26, color='gold', alpha=.5)

my_logo.ax.axvline(22.5, color='k', linewidth=1, linestyle=':')



# # style using Axes methods

my_logo.ax.set_ylabel('Frequency')


my_logo.ax.set_xlabel('Position')
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
# my_logo.ax.set_xlim([-6.0, -0.0])
ax1.tick_params(labelbottom=True)

ax2.bar(my_df.index, coverages, width=1, color='#AFAFAF')
ax2.set_ylabel('Coverage')
ax2.set_xlabel('Position')
# Out:
# Text(0.5, 0, 'Position')

# %% [markdown]
# # Flavobacteriales

# %%
my_df, coverages = create_matrix.create_matrix(
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Flavobacteriales_21_tails.aln.fasta'
#     '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Flavobacteriales_21_tails.aln_MANUAL.fasta'
)

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])

my_x_ticks =  np.array([  0,  3,  8, 13, 18, 23, 27, 28, 32, 37])
ecoli_xticks = np.array([28, 25, 20, 15, 10,  5,  1, -1, -5, -10])



# create Logo object
my_logo = logomaker.Logo(my_df,
                         ax=ax1,
                         font_name='DejaVu Sans',
                         color_scheme='colorblind_safe',
#                          vpad=.1,
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
for i in range(20, 26):
    my_logo.highlight_position(p=i, color='#BFBFBF', alpha=.7)
# end for
    
my_logo.ax.axvline(27.5, color='k', linewidth=1, linestyle=':')



# # style using Axes methods

my_logo.ax.set_ylabel('Frequency', fontsize = 12)


my_logo.ax.set_xlabel('Position', fontsize = 12)
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
# my_logo.ax.set_xlim([-6.0, -0.0])
ax1.tick_params(labelbottom=True)

ax2.bar(my_df.index, coverages, width=1, color='#AFAFAF')
ax2.set_ylabel('Coverage', fontsize = 12)
ax2.set_xlabel('Position', fontsize = 12)
# Out:
# Text(0.5, 0, 'Position')

# %%
my_df, coverages = create_matrix.create_matrix(
#     '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Flavobacteriales_21_tails.aln.fasta'
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Flavobacteriales_21_tails.aln_MANUAL.fasta'
)

# f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])


my_x_ticks =  np.array([  0,  1,  6, 11, 16, 20])
ecoli_xticks = -np.array([21, 20, 15, 10,  5,  1])



# create Logo object
my_logo = logomaker.Logo(my_df,
#                          ax=ax1,
                         font_name='DejaVu Sans',
#                          color_scheme='grays',
                         color_scheme='colorblind_safe',
#                          vpad=.1,
                         figsize=[14, 3],
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
for i in range(13, 19):
    my_logo.highlight_position(p=i, color='#BFBFBF', alpha=.7)
#     my_logo.highlight_position(p=i, color='#000000', alpha=.7)
# end for
    
# my_logo.ax.axvline(27.5, color='k', linewidth=1, linestyle=':')



# # style using Axes methods

my_logo.ax.set_ylabel('Frequency', fontsize = 12)


my_logo.ax.set_xlabel('Position', fontsize = 12)
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
# my_logo.ax.set_xlim([-6.0, -0.0])
# ax1.tick_params(labelbottom=True)

# ax2.bar(my_df.index, coverages, width=1, color='#AFAFAF')
# ax2.set_ylabel('Coverage')
# ax2.set_xlabel('Position')
# Out:
# [Text(0, 0, '-21'),
#  Text(1, 0, '-20'),
#  Text(6, 0, '-15'),
#  Text(11, 0, '-10'),
#  Text(16, 0, '-5'),
#  Text(20, 0, '-1')]

# %% [markdown]
# # Candidatus Sulcia

# %%
my_df, coverages = create_matrix.create_matrix(
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Sulcia_21_tails.aln.fasta'
)

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])

my_x_ticks =  np.array([  0,  3,  8, 13, 18, 23, 27])
ecoli_xticks = np.array([28, 25, 20, 15, 10,  5,  1])



# create Logo object
my_logo = logomaker.Logo(my_df,
                         ax=ax1,
                         font_name='DejaVu Sans',
                         color_scheme='colorblind_safe',
#                          vpad=.1,
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)


my_logo.ax.axvline(27.5, color='k', linewidth=1, linestyle=':')



# # style using Axes methods

my_logo.ax.set_ylabel('Frequency')


my_logo.ax.set_xlabel('Position')
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
# my_logo.ax.set_xlim([-6.0, -0.0])
ax1.tick_params(labelbottom=True)

ax2.bar(my_df.index, coverages, width=1, color='#AFAFAF')
ax2.set_ylabel('Coverage')
ax2.set_xlabel('Position')
# Out:
# Text(0.5, 0, 'Position')

# %% [markdown]
# # Sulfolobaceae

# %%
my_df, coverages = create_matrix.create_matrix(
#     '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Sulfolobaceae_21_tails.aln.fasta'
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Sulfolobaceae_21_tails.aln_MANUAL.fasta'
#     '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/tmp.fasta'
)

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])

my_x_ticks =  np.array([  0,  3,  8, 13, 18, 22, 23])
ecoli_xticks = np.array([23, 20, 15, 10,  5,  1, -1])

# my_x_ticks =  np.array([  0,  1,  6, 11, 16, 19, 20])
# ecoli_xticks = np.array([21, 20, 15, 10,  5,  1, -1])



# create Logo object
my_logo = logomaker.Logo(my_df,
                         ax=ax1,
                         font_name='DejaVu Sans',
                         color_scheme='colorblind_safe',
#                          vpad=.1,
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
for i in range(15, 21):
    my_logo.highlight_position(p=i, color='#BFBFBF', alpha=.7)
# end for

my_logo.ax.axvline(20.5, color='k', linewidth=1, linestyle=':')
ax2.axvline(20.5, color='k', linewidth=1, linestyle=':')



# # style using Axes methods

my_logo.ax.set_ylabel('Frequency')


my_logo.ax.set_xlabel('Position')
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
# my_logo.ax.set_xlim([-6.0, -0.0])
ax1.tick_params(labelbottom=True)

ax2.bar(my_df.index, coverages, width=1, color='#AFAFAF')
ax2.set_ylabel('Coverage')
ax2.set_xlabel('Position')
# Out:
# Text(0.5, 0, 'Position')

# %%
my_df, coverages = create_matrix.create_matrix(
#     '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Sulfolobaceae_21_tails.aln.fasta'
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Sulfolobaceae_21_tails.aln_MANUAL.fasta'
)

# f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])

my_x_ticks =   np.array([  0,  1,  6, 11, 16, 19, 20])
ecoli_xticks = -np.array([21, 20, 15, 10,  5,  2,  1])

# my_x_ticks =  np.array([  0,  1,  6, 11, 16, 19, 20])
# ecoli_xticks = np.array([21, 20, 15, 10,  5,  1, -1])



# create Logo object
my_logo = logomaker.Logo(my_df,
#                          ax=ax1,
                         font_name='DejaVu Sans',
                         color_scheme='colorblind_safe',
#                          vpad=.1,
                         figsize=[14, 3],
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
for i in range(13, 19):
    my_logo.highlight_position(p=i, color='#BFBFBF', alpha=.7)
# end for

# my_logo.ax.axvline(19.0, color='k', linewidth=1, linestyle=':')
# my_logo.ax.axvline(20.0, color='k', linewidth=1, linestyle=':')
# ax2.axvline(18.5, color='k', linewidth=1, linestyle=':')



# # style using Axes methods

my_logo.ax.set_ylabel('Frequency', fontsize=12)


my_logo.ax.set_xlabel('Position', fontsize=12)
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
my_logo.ax.set_xlim([-0.4, 20.4])
ax1.tick_params(labelbottom=True)

# ax2.bar(my_df.index, coverages, width=1, color='#AFAFAF')
# ax2.set_ylabel('Coverage')
# ax2.set_xlabel('Position')

# %%
# == Flavobacteriales ==

f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=[14, 10])
f.tight_layout(h_pad=4.5)


my_df, coverages = create_matrix.create_matrix(
#     '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Flavobacteriales_21_tails.aln.fasta'
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Flavobacteriales_21_tails.aln_MANUAL.fasta'
)

# f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])


my_x_ticks =  np.array([  0,  1,  6, 11, 16, 20])
ecoli_xticks = -np.array([21, 20, 15, 10,  5,  1])



# create Logo object
my_logo = logomaker.Logo(my_df,
                         ax=ax1,
                         font_name='DejaVu Sans',
#                          color_scheme='grays',
                         color_scheme='colorblind_safe',
#                          vpad=.1,
#                          figsize=[14, 3],
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
for i in range(13, 19):
    my_logo.highlight_position(p=i, color='#BFBFBF', alpha=.7)
#     my_logo.highlight_position(p=i, color='#000000', alpha=.7)
# end for
    
# my_logo.ax.axvline(27.5, color='k', linewidth=1, linestyle=':')



# # style using Axes methods

my_logo.ax.set_ylabel('Frequency', fontsize = 12)


my_logo.ax.set_xlabel('Position', fontsize = 12)
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
my_logo.ax.tick_params(labelbottom=True)
# my_logo.ax.set_xlim([-6.0, -0.0])
# ax1.tick_params(labelbottom=True)

# ax2.bar(my_df.index, coverages, width=1, color='#AFAFAF')
# ax2.set_ylabel('Coverage')
# ax2.set_xlabel('Position')


# == Sulfolobaceae ==

my_df, coverages = create_matrix.create_matrix(
#     '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Sulfolobaceae_21_tails.aln.fasta'
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Sulfolobaceae_21_tails.aln_MANUAL.fasta'
)

# f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])

my_x_ticks =   np.array([  0,  1,  6, 11, 16, 19, 20])
ecoli_xticks = -np.array([21, 20, 15, 10,  5,  2,  1])

# my_x_ticks =  np.array([  0,  1,  6, 11, 16, 19, 20])
# ecoli_xticks = np.array([21, 20, 15, 10,  5,  1, -1])



# create Logo object
my_logo = logomaker.Logo(my_df,
                         ax=ax2,
                         font_name='DejaVu Sans',
                         color_scheme='colorblind_safe',
#                          vpad=.1,
#                          figsize=[14, 3],
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
for i in range(13, 19):
    my_logo.highlight_position(p=i, color='#BFBFBF', alpha=.7)
# end for

# my_logo.ax.axvline(19.0, color='k', linewidth=1, linestyle=':')
# my_logo.ax.axvline(20.0, color='k', linewidth=1, linestyle=':')
# ax2.axvline(18.5, color='k', linewidth=1, linestyle=':')



# # style using Axes methods

my_logo.ax.set_ylabel('Frequency', fontsize=12)


my_logo.ax.set_xlabel('Position', fontsize=12)
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
my_logo.ax.set_xlim([-0.4, 20.4])
my_logo.ax.tick_params(labelbottom=True)

# ax2.bar(my_df.index, coverages, width=1, color='#AFAFAF')
# ax2.set_ylabel('Coverage')
# ax2.set_xlabel('Position')


# == Carsonella ==


my_df, coverages = create_matrix.create_matrix(
    '/mnt/1.5_drive_0/16S_scrubbling/antiSD/draw_seq_logos/Carsonella_21_tails.aln.fasta'
)

# f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 13])

# x = np.arange(-len(coverages), 0, 1)
# my_x_ticks = np.arange(1, 22, 1)[::-1]
my_x_ticks = np.array([0, 1, 6, 11, 16, 20])
ecoli_xticks = -np.array([21, 20, 15, 10, 5, 1])
# my_df.index = x



# create Logo object
my_logo = logomaker.Logo(my_df,
                         ax=ax3,
                         font_name='DejaVu Sans',
                         color_scheme='colorblind_safe',
#                          color_scheme='grays',
#                          vpad=.1,
#                          figsize=[14, 3],
                         width=.8)

# style using Logo methods
# my_logo.style_xticks(anchor=0, spacing=1, rotation=45)
# my_logo.highlight_position(p=2, color='gold', alpha=.5)
# my_logo.highlight_position(p=26, color='gold', alpha=.5)


# # style using Axes methods
my_logo.ax.set_ylabel('Frequency', fontsize=12)

my_logo.ax.set_xlabel('Position', fontsize=12)
my_logo.ax.set_xticks(
    my_x_ticks
)
my_logo.ax.set_xticklabels(ecoli_xticks)
my_logo.ax.tick_params(labelbottom=True)
# my_logo.ax.set_xticklabels('%d'%x for x in my_x_ticks+1)
